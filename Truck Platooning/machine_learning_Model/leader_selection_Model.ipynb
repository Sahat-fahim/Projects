# %%
# !pip install pygame
# Out:
# Requirement already satisfied: pygame in /home/fahim/.local/lib/python3.10/site-packages (2.4.0)

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Truck_data_Labeled_random_leaders.csv")
df.head()
# Out:
#    years_of_experience  aerodynamics_score  technological_score  Leader
# 0                    4                  45                   10       1
# 1                    6                  29                    7       0
# 2                    8                  34                    9       0
# 3                    5                  50                    9       1
# 4                    4                  19                    8       0

# %%
leader = df[df.Leader==1]
leader.shape
# Out:
# (1579, 4)

# %%
NOT_Leader = df[df.Leader==0]
NOT_Leader.shape
# Out:
# (3421, 4)

# %%
X = df[['years_of_experience','aerodynamics_score','technological_score']]
X.head()
# Out:
#    years_of_experience  aerodynamics_score  technological_score
# 0                    4                  45                   10
# 1                    6                  29                    7
# 2                    8                  34                    9
# 3                    5                  50                    9
# 4                    4                  19                    8

# %%
Y = df.Leader
Y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: Leader, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,train_size=0.8)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
x_pred=model.predict(X_test)

# %%
model.predict_proba(X_test)
X_test
# Out:
#       years_of_experience  aerodynamics_score  technological_score
# 1433                    2                  45                    5
# 160                     1                  44                    5
# 756                    12                  29                    5
# 3287                    2                  42                    4
# 1747                    0                  22                    7
# ...                   ...                 ...                  ...
# 2444                    3                  35                    4
# 178                     0                  14                    4
# 4065                    5                  25                    3
# 4547                    4                  19                    4
# 4850                    9                  15                    8
#
# [1000 rows x 3 columns]

# %%
model.score(X_test,Y_test)
# Out:
# 0.91

# %%
test = pd.read_csv("test.csv")
test.head()
# Out:
#    years_of_experience  aerodynamics_score  technological_score
# 0                    4                   5                   10
# 1                    2                  19                    5
# 2                    5                  20                    7

# %%
model.predict(test)
# Out:
# array([0, 0, 0])

# %%
import numpy as np
probs=model.predict_proba(test)
probs
# Out:
# array([[0.99725814, 0.00274186],
#        [0.98221585, 0.01778415],
#        [0.96601896, 0.03398104]])

# %%
arr = []
probs_percent = probs * 100
probs_percent[0][1]
leading_probability = float('-inf')
Truck_num = 0
index = 0
for row in probs_percent:
    print(row[1])
    arr.append(row[1])

sorted(arr, reverse=True)
# Out:
# 0.2741862542748329
# 1.778414761569564
# 3.3981037041600235
# [3.3981037041600235, 1.778414761569564, 0.2741862542748329]

# %%
for row in probs_percent:
    #index += 1
    if row[1] > leading_probability:
        leading_probability = row[1]
        Truck_num = index+1
    index += 1

# %%
Truck_num = 1

# %%
leading_probability
# Out:
# 3.3981037041600235

# %%
import random

follower_num = random.choice([1, 2, 3])
while follower_num == Truck_num:  # Ensure follower number is different from the predicted number
    follower_num = random.choice([1, 2, 3])
follower_num
# Out:
# 3

# %%
# Out:
# [0 0 0 0 0]
